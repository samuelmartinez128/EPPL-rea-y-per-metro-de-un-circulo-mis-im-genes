# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/Samuel_Martinez_triangulo_0096_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Samuel Martinez NL = 35 Fecha 25/mar/2026 🦊
# ---
# # Calcular Area del triangulo rectangulo
# ---
# ![Logo de Markdown](https://www.neurochispas.com/wp-content/uploads/2021/03/formula-del-area-de-un-triangulo-rectangulo.png)
#
#
# ---
# ## Formula para calcular area
# * $A=b*h/2$
# ---
# ## Datos de entrada
# $h$ ?
# $b$ ?
#
# ---
#
#
# ## Diagrama de flujo en Lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20area%20de%20triangulo.png)

# %%
# calcular area de un triangulo
# variables b,h,A
# Formulas A = b * h / 2
# Calcular el valor de b
# Calcular el valor de h
print("Calcular el area de un triangulo rectangulo")
b = float(input("Ingrese el valor de la base: "))
h = float(input("Ingrese el valor de la altura: "))
A = b * h / 2
print("El area del triangulo es: ", A)
print("Samuel Martinez NL = 35")
# Out:
# Calcular el area de un triangulo rectangulo
# Ingrese el valor de la base: 12
# Ingrese el valor de la altura: 14
# El area del triangulo es:  84.0
# Samuel Martinez NL = 35

# %% [markdown]
# # Realacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/tldraw%20DF%20y%20codigo%20triangulo%20(2).png)
