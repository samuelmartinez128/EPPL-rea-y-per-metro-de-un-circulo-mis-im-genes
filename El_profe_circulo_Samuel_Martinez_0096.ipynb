# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/blob/main/El_profe_circulo_Samuel_Martinez_0096.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Samuel Martinez NL = 35 Fecha 25/mar/2026 🦊
# ---
# # Calcular Area y Perimetro de un circulo
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/circulo_area_perimetro.PNG)
#
#
# ---
# ## Formula para calcular area
# * $A=\pi*r^2$
# ---
#
# ## Formula para calcular perimetro
# *  $P=2*\pi*r$
#
# ---
# ## Datos de entrada
# $r$ ?
#
# ---
#
#
# ## Diagrama de flujo en Lucidchart
# ![Logo de Markdown](https://raw.githubusercontent.com/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/DF%20Area%20perimetro%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A,P,r
# Formulas A = pi*r^2  y  P = 2 * pi * r
# Calcular el valor de r
import math
print("Calcular area y perimetro de un circulo")
r = float(input("Ingrese el radio del circulo: "))
A = math.pi*r**2
P = 2*math.pi*r
print("El area del circulo es: ",A)
print("El perimetro del circulo es: ",P)
print(" Samuel Martinez NL = 35")
# Out:
# Calcular area y perimetro de un circulo
# Ingrese el radio del circulo: 5
# El area del circulo es:  78.53981633974483
# El perimetro del circulo es:  31.41592653589793
#  Samuel Martinez NL = 35

# %% [markdown]
# # Realacion entre codigo y DF en tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/samuelmartinez128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes/refs/heads/main/tldraw%20DF%20y%20codigo.png)
